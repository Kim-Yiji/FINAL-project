# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler

DATA_PATH = "/content/drive/MyDrive/the_datas/data/"

SEED = 42 # 시드값

# 데이터 블러오기
import pandas as pd
import numpy as np

train_tr = pd.read_csv(f"{DATA_PATH}store_train_transactions.csv") # 학습용 구매기록 데이터
train_target = pd.read_csv(f"{DATA_PATH}store_train.csv") # 학습용 정답 데이터
test_tr = pd.read_csv(f"{DATA_PATH}store_test_transactions.csv") # 테스트용 구매기록 데이터
submit = pd.read_csv(f"{DATA_PATH}store_submission.csv") # 제출 양식 데이터

train_tr.shape , train_target.shape , test_tr.shape , submit.shape

#공통 피처 파일 불러오기
train_ft = pd.read_csv(f"{DATA_PATH}train_common_4.csv") # 학습 데이터(피처)
test_ft = pd.read_csv(f"{DATA_PATH}test_common_4.csv") # 테스트 데이터(피처)

train_tr.shape , train_target.shape , test_tr.shape , submit.shape, train_ft.shape , test_ft.shape
# Out:
# ((523105, 7), (14940, 2), (441196, 7), (12225, 2), (14940, 450), (12225, 450))

# %%
target = train_target["target"]
target
# Out:
# 0        1.0
# 1        1.0
# 2        0.0
# 3        0.0
# 4        0.0
#         ...
# 14935    0.0
# 14936    0.0
# 14937    0.0
# 14938    1.0
# 14939    1.0
# Name: target, Length: 14940, dtype: float64

# %% [markdown]
# # AutoML(Automated machine learning)
# - 시간 소모적이고 반복적인 기계 학습 모델 개발 작업을 자동화하는 프로세스
# - 데이터 과학자, 분석가 및 개발자는 모델 품질을 유지하면서 확장성, 효율성 및 생산성이 높은 ML 모델을 빌드할 수 있다.

# %% [markdown]
# ## FLAML(A Fast Library for Automated Machine Learning & Tuning)
# - 머신러닝 학습 및 하이퍼파라미터 튜닝을 자동화해 주는 라이브러리
# - https://microsoft.github.io/FLAML/docs/Use-Cases/Task-Oriented-AutoML
# - flaml 설치하기
#     ```bash
#     pip install flaml
#     ```

# %%
pip install flaml
# Out:
# Collecting flaml
#   Downloading FLAML-2.3.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: NumPy>=1.17 in /usr/local/lib/python3.10/dist-packages (from flaml) (1.26.4)
# Downloading FLAML-2.3.2-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: flaml
# Successfully installed flaml-2.3.2

# %% [markdown]
# - `AutoML` 클래스의 `fit` 메서드 주요 파라미터
#     - metric
#         - 평가지표
#         - ex) 'roc_auc'
#     - task
#         - 작업 유형
#         - ex) 'classification'
#     - estimator_list
#         - FLAML에서 제공해주는 모델들의 별칭을 리스트에 넣어주면 된다.
#         - 생략시 자동으로 모델들이 선택된다.
#         - ex) ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
#     - time_budget
#         - 수행 시간
#             - 초단위
#     - ensemble
#         - 튜닝 후 스태킹 앙상블 여부
#         - False(기본값) : 최상의 모델을 선택해서 학습
#         - True: 스태킹하여 앙상블
#         - `dict` 예시
#             - {'final_estimator' : 사이킷런 모델 객체 }
#     - n_splits
#         - 교차검증 폴드 수(기본 5)
#     - seed
#         - 시드값
#     - early_stop
#         - True or False(기본값)
#         - 튜닝이 수렴할 경우 조기 중지여부

# %%
from flaml import AutoML
automl = AutoML()
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 8.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 9.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.1 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# %pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.6 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
params = {
    "metric": 'macro_f1',
    "task": 'classification',
    #"estimator_list" : ['xgboost', 'xgb_limitdepth', 'rf', 'lgbm', 'lgbm_spark', 'rf_spark', 'lrl1', 'lrl2', 'catboost', 'extra_tree', 'kneighbor', 'transformer', 'transformer_ms', 'histgb', 'svc', 'sgd', 'nb_spark', 'enet', 'lassolars', 'glr_spark', 'lr_spark', 'svc_spark', 'gbt_spark', 'aft_spark'],
    "estimator_list" : ['histgb','catboost', 'lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1'],
    "time_budget": 60*60,
    "seed" : SEED,
    "early_stop": True,
    # "ensemble" : True
}
automl.fit(train_ft, target, **params)
# Out:
# [flaml.automl.logger: 11-13 13:13:24] {1728} INFO - task = classification
# [flaml.automl.logger: 11-13 13:13:24] {1739} INFO - Evaluation method: cv
# [flaml.automl.logger: 11-13 13:13:25] {1838} INFO - Minimizing error metric: 1-macro_f1
# [flaml.automl.logger: 11-13 13:13:25] {1955} INFO - List of ML learners in AutoML Run: ['histgb', 'catboost', 'lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl.logger: 11-13 13:13:25] {2258} INFO - iteration 0, current learner histgb
# [flaml.automl.logger: 11-13 13:13:37] {2393} INFO - Estimated sufficient time budget=127411s. Estimated necessary time budget=3141s.
# [flaml.automl.logger: 11-13 13:13:37] {2442} INFO -  at 17.2s,	estimator histgb's best error=0.6223,	best estimator histgb's best error=0.6223
# [flaml.automl.logger: 11-13 13:13:37] {2258} INFO - iteration 1, current learner histgb
# [flaml.automl.logger: 11-13 13:13:48] {2442} INFO -  at 27.9s,	estimator histgb's best error=0.6223,	best estimator histgb's best error=0.6223
# [flaml.automl.logger: 11-13 13:13:48] {2258} INFO - iteration 2, current learner histgb
# [flaml.automl.logger: 11-13 13:13:56] {2442} INFO -  at 35.9s,	estimator histgb's best error=0.3659,	best estimator histgb's best error=0.3659
# [flaml.automl.logger: 11-13 13:13:56] {2258} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 11-13 13:14:07] {2442} INFO -  at 46.6s,	estimator lgbm's best error=0.6223,	best estimator histgb's best error=0.3659
# [flaml.automl.logger: 11-13 13:14:07] {2258} INFO - iteration 4, current learner histgb
# [flaml.automl.logger: 11-13 13:14:24] {2442} INFO -  at 63.7s,	estimator histgb's best error=0.3441,	best estimator histgb's best error=0.3441
# [flaml.automl.logger: 11-13 13:14:24] {2258} INFO - iteration 5, current learner histgb
# [flaml.automl.logger: 11-13 13:14:30] {2442} INFO -  at 69.9s,	estimator histgb's best error=0.3441,	best estimator histgb's best error=0.3441
# [flaml.automl.logger: 11-13 13:14:30] {2258} INFO - iteration 6, current learner histgb
# [flaml.automl.logger: 11-13 13:14:38] {2442} INFO -  at 77.9s,	estimator histgb's best error=0.3441,	best estimator histgb's best error=0.3441
# [flaml.automl.logger: 11-13 13:14:38] {2258} INFO - iteration 7, current learner histgb
# [flaml.automl.logger: 11-13 13:14:54] {2442} INFO -  at 93.9s,	estimator histgb's best error=0.3006,	best estimator histgb's best error=0.3006
# [flaml.automl.logger: 11-13 13:14:54] {2258} INFO - iteration 8, current learner histgb
# [flaml.automl.logger: 11-13 13:15:04] {2442} INFO -  at 104.1s,	estimator histgb's best error=0.3006,	best estimator histgb's best error=0.3006
# [flaml.automl.logger: 11-13 13:15:04] {2258} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 11-13 13:15:09] {2442} INFO -  at 109.0s,	estimator lgbm's best error=0.6223,	best estimator histgb's best error=0.3006
# [flaml.automl.logger: 11-13 13:15:09] {2258} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 11-13 13:15:12] {2442} INFO -  at 112.0s,	estimator lgbm's best error=0.3951,	best estimator histgb's best error=0.3006
# [flaml.automl.logger: 11-13 13:15:12] {2258} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 11-13 13:15:15] {2442} INFO -  at 115.1s,	estimator lgbm's best error=0.3219,	best estimator histgb's best error=0.3006
# [flaml.automl.logger: 11-13 13:15:15] {2258} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 11-13 13:15:21] {2442} INFO -  at 121.4s,	estimator lgbm's best error=0.3219,	best estimator histgb's best error=0.3006
# [flaml.automl.logger: 11-13 13:15:21] {2258} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 11-13 13:15:26] {2442} INFO -  at 125.5s,	estimator lgbm's best error=0.3099,	best estimator histgb's best error=0.3006
# [flaml.automl.logger: 11-13 13:15:26] {2258} INFO - iteration 14, current learner histgb
# [flaml.automl.logger: 11-13 13:15:54] {2442} INFO -  at 154.1s,	estimator histgb's best error=0.2910,	best estimator histgb's best error=0.2910
# [flaml.automl.logger: 11-13 13:15:54] {2258} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 11-13 13:15:59] {2442} INFO -  at 158.9s,	estimator xgboost's best error=0.6223,	best estimator histgb's best error=0.2910
# [flaml.automl.logger: 11-13 13:15:59] {2258} INFO - iteration 16, current learner xgboost
# [flaml.automl.logger: 11-13 13:16:06] {2442} INFO -  at 166.2s,	estimator xgboost's best error=0.6223,	best estimator histgb's best error=0.2910
# [flaml.automl.logger: 11-13 13:16:06] {2258} INFO - iteration 17, current learner histgb
# [flaml.automl.logger: 11-13 13:16:34] {2442} INFO -  at 193.7s,	estimator histgb's best error=0.2910,	best estimator histgb's best error=0.2910
# [flaml.automl.logger: 11-13 13:16:34] {2258} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 11-13 13:16:39] {2442} INFO -  at 199.1s,	estimator xgboost's best error=0.3910,	best estimator histgb's best error=0.2910
# [flaml.automl.logger: 11-13 13:16:39] {2258} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 11-13 13:16:45] {2442} INFO -  at 204.6s,	estimator lgbm's best error=0.2884,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:16:45] {2258} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 11-13 13:16:52] {2442} INFO -  at 212.1s,	estimator lgbm's best error=0.2884,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:16:52] {2258} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 11-13 13:16:58] {2442} INFO -  at 217.4s,	estimator lgbm's best error=0.2884,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:16:58] {2258} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 11-13 13:17:07] {2442} INFO -  at 227.0s,	estimator lgbm's best error=0.2884,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:17:07] {2258} INFO - iteration 23, current learner xgboost
# [flaml.automl.logger: 11-13 13:17:12] {2442} INFO -  at 232.0s,	estimator xgboost's best error=0.3910,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:17:12] {2258} INFO - iteration 24, current learner xgboost
# [flaml.automl.logger: 11-13 13:17:22] {2442} INFO -  at 242.2s,	estimator xgboost's best error=0.3147,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:17:22] {2258} INFO - iteration 25, current learner lgbm
# [flaml.automl.logger: 11-13 13:17:38] {2442} INFO -  at 257.7s,	estimator lgbm's best error=0.2884,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:17:38] {2258} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 11-13 13:17:43] {2442} INFO -  at 262.9s,	estimator xgboost's best error=0.3147,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:17:43] {2258} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 11-13 13:17:57] {2442} INFO -  at 276.7s,	estimator xgboost's best error=0.3052,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:17:57] {2258} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 11-13 13:17:58] {2442} INFO -  at 277.9s,	estimator extra_tree's best error=0.6223,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:17:58] {2258} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 11-13 13:18:00] {2442} INFO -  at 279.8s,	estimator extra_tree's best error=0.6223,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:18:00] {2258} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 11-13 13:18:06] {2442} INFO -  at 286.3s,	estimator lgbm's best error=0.2884,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:18:06] {2258} INFO - iteration 31, current learner histgb
# [flaml.automl.logger: 11-13 13:18:28] {2442} INFO -  at 307.6s,	estimator histgb's best error=0.2895,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:18:28] {2258} INFO - iteration 32, current learner extra_tree
# [flaml.automl.logger: 11-13 13:18:29] {2442} INFO -  at 309.1s,	estimator extra_tree's best error=0.5198,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:18:29] {2258} INFO - iteration 33, current learner extra_tree
# [flaml.automl.logger: 11-13 13:18:31] {2442} INFO -  at 311.2s,	estimator extra_tree's best error=0.4534,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:18:31] {2258} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 11-13 13:18:36] {2442} INFO -  at 316.3s,	estimator lgbm's best error=0.2884,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:18:36] {2258} INFO - iteration 35, current learner extra_tree
# [flaml.automl.logger: 11-13 13:18:38] {2442} INFO -  at 317.5s,	estimator extra_tree's best error=0.4534,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:18:38] {2258} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 11-13 13:18:39] {2442} INFO -  at 319.3s,	estimator extra_tree's best error=0.4534,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:18:39] {2258} INFO - iteration 37, current learner xgboost
# [flaml.automl.logger: 11-13 13:19:04] {2442} INFO -  at 343.8s,	estimator xgboost's best error=0.2951,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:19:04] {2258} INFO - iteration 38, current learner extra_tree
# [flaml.automl.logger: 11-13 13:19:05] {2442} INFO -  at 345.3s,	estimator extra_tree's best error=0.4274,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:19:05] {2258} INFO - iteration 39, current learner rf
# [flaml.automl.logger: 11-13 13:19:07] {2442} INFO -  at 346.5s,	estimator rf's best error=0.4774,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:19:07] {2258} INFO - iteration 40, current learner rf
# [flaml.automl.logger: 11-13 13:19:08] {2442} INFO -  at 348.2s,	estimator rf's best error=0.4774,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:19:08] {2258} INFO - iteration 41, current learner rf
# [flaml.automl.logger: 11-13 13:19:10] {2442} INFO -  at 349.8s,	estimator rf's best error=0.3879,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:19:10] {2258} INFO - iteration 42, current learner xgboost
# [flaml.automl.logger: 11-13 13:19:24] {2442} INFO -  at 364.2s,	estimator xgboost's best error=0.2951,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:19:24] {2258} INFO - iteration 43, current learner histgb
# [flaml.automl.logger: 11-13 13:19:35] {2442} INFO -  at 375.3s,	estimator histgb's best error=0.2895,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:19:35] {2258} INFO - iteration 44, current learner rf
# [flaml.automl.logger: 11-13 13:19:37] {2442} INFO -  at 377.1s,	estimator rf's best error=0.3796,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:19:37] {2258} INFO - iteration 45, current learner extra_tree
# [flaml.automl.logger: 11-13 13:19:39] {2442} INFO -  at 378.5s,	estimator extra_tree's best error=0.4255,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:19:39] {2258} INFO - iteration 46, current learner xgboost
# [flaml.automl.logger: 11-13 13:19:55] {2442} INFO -  at 394.5s,	estimator xgboost's best error=0.2951,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:19:55] {2258} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 11-13 13:20:05] {2442} INFO -  at 404.9s,	estimator lgbm's best error=0.2884,	best estimator lgbm's best error=0.2884
# [flaml.automl.logger: 11-13 13:20:05] {2258} INFO - iteration 48, current learner xgboost
# [flaml.automl.logger: 11-13 13:20:39] {2442} INFO -  at 438.5s,	estimator xgboost's best error=0.2870,	best estimator xgboost's best error=0.2870
# [flaml.automl.logger: 11-13 13:20:39] {2258} INFO - iteration 49, current learner lgbm
# [flaml.automl.logger: 11-13 13:21:05] {2442} INFO -  at 464.7s,	estimator lgbm's best error=0.2884,	best estimator xgboost's best error=0.2870
# [flaml.automl.logger: 11-13 13:21:05] {2258} INFO - iteration 50, current learner rf
# [flaml.automl.logger: 11-13 13:21:06] {2442} INFO -  at 466.4s,	estimator rf's best error=0.3796,	best estimator xgboost's best error=0.2870
# [flaml.automl.logger: 11-13 13:21:06] {2258} INFO - iteration 51, current learner extra_tree
# [flaml.automl.logger: 11-13 13:21:09] {2442} INFO -  at 469.1s,	estimator extra_tree's best error=0.4255,	best estimator xgboost's best error=0.2870
# [flaml.automl.logger: 11-13 13:21:09] {2258} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 11-13 13:21:14] {2442} INFO -  at 474.4s,	estimator lgbm's best error=0.2884,	best estimator xgboost's best error=0.2870
# [flaml.automl.logger: 11-13 13:21:14] {2258} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 11-13 13:21:18] {2442} INFO -  at 477.5s,	estimator lgbm's best error=0.2884,	best estimator xgboost's best error=0.2870
# [flaml.automl.logger: 11-13 13:21:18] {2258} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 11-13 13:21:37] {2442} INFO -  at 496.6s,	estimator lgbm's best error=0.2884,	best estimator xgboost's best error=0.2870
# [flaml.automl.logger: 11-13 13:21:37] {2258} INFO - iteration 55, current learner histgb
# [flaml.automl.logger: 11-13 13:22:12] {2442} INFO -  at 531.6s,	estimator histgb's best error=0.2864,	best estimator histgb's best error=0.2864
# [flaml.automl.logger: 11-13 13:22:12] {2258} INFO - iteration 56, current learner rf
# [flaml.automl.logger: 11-13 13:22:15] {2442} INFO -  at 534.7s,	estimator rf's best error=0.3796,	best estimator histgb's best error=0.2864
# [flaml.automl.logger: 11-13 13:22:15] {2258} INFO - iteration 57, current learner histgb
# [flaml.automl.logger: 11-13 13:22:34] {2442} INFO -  at 554.1s,	estimator histgb's best error=0.2864,	best estimator histgb's best error=0.2864
# [flaml.automl.logger: 11-13 13:22:34] {2258} INFO - iteration 58, current learner histgb
# [flaml.automl.logger: 11-13 13:23:34] {2442} INFO -  at 613.6s,	estimator histgb's best error=0.2861,	best estimator histgb's best error=0.2861
# [flaml.automl.logger: 11-13 13:23:34] {2258} INFO - iteration 59, current learner rf
# [flaml.automl.logger: 11-13 13:23:36] {2442} INFO -  at 616.1s,	estimator rf's best error=0.3706,	best estimator histgb's best error=0.2861
# [flaml.automl.logger: 11-13 13:23:36] {2258} INFO - iteration 60, current learner histgb
# [flaml.automl.logger: 11-13 13:25:00] {2442} INFO -  at 699.6s,	estimator histgb's best error=0.2831,	best estimator histgb's best error=0.2831
# [flaml.automl.logger: 11-13 13:25:00] {2258} INFO - iteration 61, current learner rf
# [flaml.automl.logger: 11-13 13:25:02] {2442} INFO -  at 702.2s,	estimator rf's best error=0.3613,	best estimator histgb's best error=0.2831
# [flaml.automl.logger: 11-13 13:25:02] {2258} INFO - iteration 62, current learner histgb
# [flaml.automl.logger: 11-13 13:26:02] {2442} INFO -  at 761.8s,	estimator histgb's best error=0.2831,	best estimator histgb's best error=0.2831
# [flaml.automl.logger: 11-13 13:26:02] {2258} INFO - iteration 63, current learner rf
# [flaml.automl.logger: 11-13 13:26:06] {2442} INFO -  at 765.7s,	estimator rf's best error=0.3577,	best estimator histgb's best error=0.2831
# [flaml.automl.logger: 11-13 13:26:06] {2258} INFO - iteration 64, current learner xgboost
# [flaml.automl.logger: 11-13 13:26:22] {2442} INFO -  at 782.2s,	estimator xgboost's best error=0.2870,	best estimator histgb's best error=0.2831
# [flaml.automl.logger: 11-13 13:26:22] {2258} INFO - iteration 65, current learner histgb
# [flaml.automl.logger: 11-13 13:29:01] {2442} INFO -  at 940.4s,	estimator histgb's best error=0.2831,	best estimator histgb's best error=0.2831
# [flaml.automl.logger: 11-13 13:29:01] {2258} INFO - iteration 66, current learner rf
# [flaml.automl.logger: 11-13 13:29:06] {2442} INFO -  at 945.4s,	estimator rf's best error=0.3577,	best estimator histgb's best error=0.2831
# [flaml.automl.logger: 11-13 13:29:06] {2258} INFO - iteration 67, current learner xgboost
# [flaml.automl.logger: 11-13 13:30:37] {2442} INFO -  at 1036.5s,	estimator xgboost's best error=0.2870,	best estimator histgb's best error=0.2831
# [flaml.automl.logger: 11-13 13:30:37] {2258} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 11-13 13:30:50] {2442} INFO -  at 1049.8s,	estimator lgbm's best error=0.2852,	best estimator histgb's best error=0.2831
# [flaml.automl.logger: 11-13 13:30:50] {2258} INFO - iteration 69, current learner histgb
# [flaml.automl.logger: 11-13 13:31:37] {2442} INFO -  at 1096.5s,	estimator histgb's best error=0.2829,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:31:37] {2258} INFO - iteration 70, current learner rf
# [flaml.automl.logger: 11-13 13:31:39] {2442} INFO -  at 1099.1s,	estimator rf's best error=0.3486,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:31:39] {2258} INFO - iteration 71, current learner rf
# [flaml.automl.logger: 11-13 13:31:43] {2442} INFO -  at 1102.5s,	estimator rf's best error=0.3344,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:31:43] {2258} INFO - iteration 72, current learner rf
# [flaml.automl.logger: 11-13 13:31:45] {2442} INFO -  at 1104.5s,	estimator rf's best error=0.3344,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:31:45] {2258} INFO - iteration 73, current learner xgboost
# [flaml.automl.logger: 11-13 13:31:58] {2442} INFO -  at 1117.7s,	estimator xgboost's best error=0.2870,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:31:58] {2258} INFO - iteration 74, current learner rf
# [flaml.automl.logger: 11-13 13:32:01] {2442} INFO -  at 1121.1s,	estimator rf's best error=0.3336,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:32:01] {2258} INFO - iteration 75, current learner xgboost
# [flaml.automl.logger: 11-13 13:33:54] {2442} INFO -  at 1233.8s,	estimator xgboost's best error=0.2840,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:33:54] {2258} INFO - iteration 76, current learner histgb
# [flaml.automl.logger: 11-13 13:34:19] {2442} INFO -  at 1259.2s,	estimator histgb's best error=0.2829,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:34:19] {2258} INFO - iteration 77, current learner histgb
# [flaml.automl.logger: 11-13 13:35:47] {2442} INFO -  at 1347.0s,	estimator histgb's best error=0.2829,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:35:47] {2258} INFO - iteration 78, current learner xgboost
# [flaml.automl.logger: 11-13 13:36:56] {2442} INFO -  at 1416.0s,	estimator xgboost's best error=0.2840,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:36:56] {2258} INFO - iteration 79, current learner lgbm
# [flaml.automl.logger: 11-13 13:37:04] {2442} INFO -  at 1423.9s,	estimator lgbm's best error=0.2852,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:37:04] {2258} INFO - iteration 80, current learner catboost
# [flaml.automl.logger: 11-13 13:38:11] {2442} INFO -  at 1490.5s,	estimator catboost's best error=0.2933,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:38:11] {2258} INFO - iteration 81, current learner catboost
# [flaml.automl.logger: 11-13 13:40:26] {2442} INFO -  at 1626.1s,	estimator catboost's best error=0.2890,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:40:26] {2258} INFO - iteration 82, current learner extra_tree
# [flaml.automl.logger: 11-13 13:40:28] {2442} INFO -  at 1627.8s,	estimator extra_tree's best error=0.4255,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:40:28] {2258} INFO - iteration 83, current learner catboost
# [flaml.automl.logger: 11-13 13:43:37] {2442} INFO -  at 1817.2s,	estimator catboost's best error=0.2890,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:43:37] {2258} INFO - iteration 84, current learner xgboost
# [flaml.automl.logger: 11-13 13:49:21] {2442} INFO -  at 2161.2s,	estimator xgboost's best error=0.2840,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:49:21] {2258} INFO - iteration 85, current learner rf
# [flaml.automl.logger: 11-13 13:49:24] {2442} INFO -  at 2163.5s,	estimator rf's best error=0.3336,	best estimator histgb's best error=0.2829
# [flaml.automl.logger: 11-13 13:49:24] {2258} INFO - iteration 86, current learner xgboost
# [flaml.automl.logger: 11-13 13:55:33] {2442} INFO -  at 2533.0s,	estimator xgboost's best error=0.2797,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 13:55:33] {2258} INFO - iteration 87, current learner xgboost
# [flaml.automl.logger: 11-13 13:57:24] {2442} INFO -  at 2643.7s,	estimator xgboost's best error=0.2797,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 13:57:24] {2258} INFO - iteration 88, current learner xgboost
# [flaml.automl.logger: 11-13 14:06:50] {2442} INFO -  at 3210.3s,	estimator xgboost's best error=0.2797,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:06:50] {2258} INFO - iteration 89, current learner lgbm
# [flaml.automl.logger: 11-13 14:07:06] {2442} INFO -  at 3225.6s,	estimator lgbm's best error=0.2850,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:07:06] {2258} INFO - iteration 90, current learner lgbm
# [flaml.automl.logger: 11-13 14:07:18] {2442} INFO -  at 3238.2s,	estimator lgbm's best error=0.2850,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:07:18] {2258} INFO - iteration 91, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 14:07:30] {2442} INFO -  at 3250.0s,	estimator xgb_limitdepth's best error=0.3093,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:07:30] {2258} INFO - iteration 92, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 14:07:40] {2442} INFO -  at 3260.3s,	estimator xgb_limitdepth's best error=0.3093,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:07:40] {2258} INFO - iteration 93, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 14:07:50] {2442} INFO -  at 3270.2s,	estimator xgb_limitdepth's best error=0.3093,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:07:50] {2258} INFO - iteration 94, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 14:08:01] {2442} INFO -  at 3280.9s,	estimator xgb_limitdepth's best error=0.3093,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:08:01] {2258} INFO - iteration 95, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 14:08:14] {2442} INFO -  at 3294.3s,	estimator xgb_limitdepth's best error=0.3093,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:08:14] {2258} INFO - iteration 96, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 14:08:20] {2442} INFO -  at 3300.0s,	estimator xgb_limitdepth's best error=0.3093,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:08:20] {2258} INFO - iteration 97, current learner extra_tree
# [flaml.automl.logger: 11-13 14:08:22] {2442} INFO -  at 3301.9s,	estimator extra_tree's best error=0.3991,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:08:22] {2258} INFO - iteration 98, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 14:08:45] {2442} INFO -  at 3324.7s,	estimator xgb_limitdepth's best error=0.3034,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:08:45] {2258} INFO - iteration 99, current learner extra_tree
# [flaml.automl.logger: 11-13 14:08:46] {2442} INFO -  at 3326.3s,	estimator extra_tree's best error=0.3792,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:08:46] {2258} INFO - iteration 100, current learner extra_tree
# [flaml.automl.logger: 11-13 14:08:48] {2442} INFO -  at 3327.7s,	estimator extra_tree's best error=0.3792,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:08:48] {2258} INFO - iteration 101, current learner extra_tree
# [flaml.automl.logger: 11-13 14:08:50] {2442} INFO -  at 3329.9s,	estimator extra_tree's best error=0.3657,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:08:50] {2258} INFO - iteration 102, current learner extra_tree
# [flaml.automl.logger: 11-13 14:08:52] {2442} INFO -  at 3332.4s,	estimator extra_tree's best error=0.3657,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:08:52] {2258} INFO - iteration 103, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 14:09:33] {2442} INFO -  at 3373.0s,	estimator xgb_limitdepth's best error=0.2878,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:09:33] {2258} INFO - iteration 104, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 14:09:57] {2442} INFO -  at 3397.0s,	estimator xgb_limitdepth's best error=0.2878,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:09:57] {2258} INFO - iteration 105, current learner catboost
# [flaml.automl.logger: 11-13 14:11:35] {2442} INFO -  at 3494.6s,	estimator catboost's best error=0.2863,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:11:35] {2258} INFO - iteration 106, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 14:11:59] {2442} INFO -  at 3518.9s,	estimator xgb_limitdepth's best error=0.2878,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:11:59] {2258} INFO - iteration 107, current learner extra_tree
# [flaml.automl.logger: 11-13 14:12:01] {2442} INFO -  at 3521.0s,	estimator extra_tree's best error=0.3657,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:12:01] {2258} INFO - iteration 108, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 14:13:15] {2442} INFO -  at 3595.2s,	estimator xgb_limitdepth's best error=0.2866,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:13:15] {2258} INFO - iteration 109, current learner extra_tree
# [flaml.automl.logger: 11-13 14:13:18] {2442} INFO -  at 3598.3s,	estimator extra_tree's best error=0.3578,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:13:18] {2258} INFO - iteration 110, current learner lrl1
# INFO:flaml.tune.searcher.blendsearch:No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 11-13 14:14:34] {2442} INFO -  at 3673.7s,	estimator lrl1's best error=0.6222,	best estimator xgboost's best error=0.2797
# [flaml.automl.logger: 11-13 14:15:55] {2685} INFO - retrain xgboost for 81.2s
# [flaml.automl.logger: 11-13 14:15:55] {2688} INFO - retrained model: XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=0.8411207958761456, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy='lossguide', importance_type=None,
#               interaction_constraints=None, learning_rate=0.017361801680067852,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=0, max_leaves=4,
#               min_child_weight=1.3061479700751337, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=2519,
#               n_jobs=-1, num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 11-13 14:15:55] {1985} INFO - fit succeeded
# [flaml.automl.logger: 11-13 14:15:55] {1986} INFO - Time taken to find the best model: 2533.038224697113

# %% [markdown]
# - 선택된 모델 객체 확인

# %%
automl.model.estimator
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=0.8411207958761456, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy='lossguide', importance_type=None,
#               interaction_constraints=None, learning_rate=0.017361801680067852,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=0, max_leaves=4,
#               min_child_weight=1.3061479700751337, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=2519,
#               n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# - 튜닝된 하이퍼파라미터

# %%
automl.best_config
# Out:
# {'n_estimators': 2519,
#  'max_leaves': 4,
#  'min_child_weight': 1.3061479700751337,
#  'learning_rate': 0.017361801680067852,
#  'subsample': 0.8539985606622676,
#  'colsample_bylevel': 0.8411207958761456,
#  'colsample_bytree': 1.0,
#  'reg_alpha': 0.004074821343348109,
#  'reg_lambda': 6.547882344386646}

# %% [markdown]
# - 선택된 모델의 cv 점수 확인하기

# %%
1 - automl.best_loss
# Out:
# 0.7202511492829202

# %% [markdown]
# - 예측 가능

# %%
pred = automl.predict(test_ft)
pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
pred_proba = automl.predict_proba(test_ft) #여기서 실수해서 앙상블 파일에서 후처리함
pred_proba
# Out:
# array([[0.9032815 , 0.09671848],
#        [0.61545503, 0.38454494],
#        [0.70975727, 0.29024273],
#        ...,
#        [0.95313144, 0.04686856],
#        [0.8543746 , 0.14562543],
#        [0.9727974 , 0.02720259]], dtype=float32)

# %% [markdown]
# # 정답 데이터

# %%
submit
# Out:
#                ID  target
# 0          test_0     0.5
# 1          test_1     0.5
# 2          test_2     0.5
# 3          test_3     0.5
# 4          test_4     0.5
# ...           ...     ...
# 12220  test_12220     0.5
# 12221  test_12221     0.5
# 12222  test_12222     0.5
# 12223  test_12223     0.5
# 12224  test_12224     0.5
#
# [12225 rows x 2 columns]

# %%
submit["target"] = pred
submit
# Out:
#                ID  target
# 0          test_0     0.0
# 1          test_1     0.0
# 2          test_2     0.0
# 3          test_3     1.0
# 4          test_4     1.0
# ...           ...     ...
# 12220  test_12220     1.0
# 12221  test_12221     0.0
# 12222  test_12222     0.0
# 12223  test_12223     0.0
# 12224  test_12224     0.0
#
# [12225 rows x 2 columns]

# %% [markdown]
# #업로드

# %%
submit.to_csv(f"{DATA_PATH}submit_새출발_automl_3.csv",index=False)
